# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from IPython import display
from utils import convert_audio_image, conf

# %%
convert_audio_image('example.wav')
# Out:
# [('./tmp/example_0.wav', './tmp/example_0.png'),
#  ('./tmp/example_1.wav', './tmp/example_1.png'),
#  ('./tmp/example_2.wav', './tmp/example_2.png'),
#  ('./tmp/example_3.wav', './tmp/example_3.png'),
#  ('./tmp/example_4.wav', './tmp/example_4.png'),
#  ('./tmp/example_5.wav', './tmp/example_5.png'),
#  ('./tmp/example_6.wav', './tmp/example_6.png'),
#  ('./tmp/example_7.wav', './tmp/example_7.png'),
#  ('./tmp/example_8.wav', './tmp/example_8.png'),
#  ('./tmp/example_9.wav', './tmp/example_9.png'),
#  ('./tmp/example_10.wav', './tmp/example_10.png')]

# %%
from IPython import display

display.Audio('./tmp/example_0.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython import display

display.Image('./tmp/example_7.png')

# %%
display.Audio('example.wav')

# %%
import numpy as np

# %%
np.pad

# %%
np.append(np.array([2, 3]), np.array([4, 5]))

# %%
'example.wav'.plit

# %%
import librosa

# %%
x, sr = librosa.load('./example.wav', sr=conf.sampling_rate)

# %%
x.shape

# %%
librosa.output.write_wav('./example_out.wav', x[:50000], sr)

# %%
display.Audio('./example_out.wav')

# %%
# !ls -la ./tmp
# Out:
# total 27504
# drwxr-xr-x 2 aakashns docker      4096 Aug  9 13:10 .
# drwxr-xr-x 6 aakashns docker      4096 Aug  9 13:20 ..
# -rw-r--r-- 1 aakashns aakashns    8906 Aug  9 12:43 100032-3-0-0_0.png
# -rw-r--r-- 1 aakashns docker   8283400 Aug  9 12:07 example.wav
# -rw-r--r-- 1 aakashns aakashns   67010 Aug  9 13:11 example_0.png
# -rw-r--r-- 1 aakashns aakashns 1411258 Aug  9 13:20 example_0.wav
# -rw-r--r-- 1 aakashns aakashns   81011 Aug  9 13:11 example_1.png
# -rw-r--r-- 1 aakashns aakashns 1411258 Aug  9 13:20 example_1.wav
# -rw-r--r-- 1 aakashns aakashns   44513 Aug  9 13:11 example_10.png
# -rw-r--r-- 1 aakashns aakashns 1411258 Aug  9 13:20 example_10.wav
# -rw-r--r-- 1 aakashns aakashns  120110 Aug  9 13:11 example_2.png
# -rw-r--r-- 1 aakashns aakashns 1411258 Aug  9 13:20 example_2.wav
# -rw-r--r-- 1 aakashns aakashns   95492 Aug  9 13:11 example_3.png
# -rw-r--r-- 1 aakashns aakashns 1411258 Aug  9 13:20 example_3.wav
# ...
